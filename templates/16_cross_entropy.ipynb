# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/16_cross_entropy.ipynb)
#
# # 🟢 Easy: Cross-Entropy Loss
#
# Implement **cross-entropy loss** from scratch.
#
# $$\text{CE}(x, y) = -\log\frac{e^{x_y}}{\sum_j e^{x_j}}$$
#
# ### Signature
# ```python
# def cross_entropy_loss(logits: Tensor, targets: Tensor) -> Tensor:
#     # logits: (B, C) float, targets: (B,) long indices
#     # Returns: scalar loss (mean over batch)
# ```
#
# ### Rules
# - Do NOT use `F.cross_entropy` or `nn.CrossEntropyLoss`
# - Must be numerically stable (use logsumexp trick)

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.3 MB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def cross_entropy_loss(logits, targets):
  max_logits = logits.max(dim=1, keepdim=True).values
  exp_logits = torch.exp(logits - max_logits)
  sum_exp_logits = exp_logits.sum(dim=1, keepdim=True)
  log_sum_exp_logits = max_logits + torch.log(sum_exp_logits)

  log_softmax = logits - log_sum_exp_logits

  # gather(dim, index) 是 PyTorch 中一个非常强大的操作。它的作用是根据 index 张量中提供的索引，沿着 dim 指定的维度，从源张量中收集元素。
  log_probs_for_targets = log_softmax.gather(1, targets.unsqueeze(1)).squeeze(1)
  return -1 * log_probs_for_targets.mean()

# %%
# 🧪 Debug
logits = torch.randn(4, 10)
targets = torch.randint(0, 10, (4,))
print('Loss:', cross_entropy_loss(logits, targets))
print('Ref: ', torch.nn.functional.cross_entropy(logits, targets))
# Out:
# Loss: tensor(2.4274)
# Ref:  tensor(2.4274)

# %%
# ✅ SUBMIT
from torch_judge import check
check('cross_entropy')
# Out:
# 🧪 Testing: Cross-Entropy Loss (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Matches F.cross_entropy (4.0ms)
#   ✅ [2/4] Numerical stability (0.8ms)
#   ✅ [3/4] Scalar output (0.4ms)
#   ✅ [4/4] Gradient flow (1.3ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (6.4ms total)
#   Progress saved. Run status() to see your dashboard.

# %% [markdown]
# prompts:
#
#
# 给我intuitive的讲一下这个函数是干嘛的 然后给我代码
#
# 不要再cell里面写 直接再聊天框里给我讲
#
# 给我implement cross_entropy_loss 这个函数的结果 再对话框里写出来
